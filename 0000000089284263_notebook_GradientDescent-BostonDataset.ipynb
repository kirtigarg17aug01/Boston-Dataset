# %% [markdown]
# - I changed the names of the given files of boston training and testing data to "boston_train" and "boston_test".

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %% [markdown]
# ### When data is not scaled.

# %%
def step_gradient(points, learning_rate, m):
    mslope = np.zeros(14)
    M = len(points)
    for i in range(M):
        x = np.array(points[i, 0:14])
        y = points[i,14]
        mslope += (-2/M)*(y-(m*x).sum())*x
    new_m = m - learning_rate*mslope
    return new_m

# %%
def cost(points, m):
    C = 0
    M = len(points)
    for i in range(M):
        x = np.array(points[i,0:14])
        y = points[i,14]
        C += (1/M)*((y-(m*x).sum())**2)
    return C

# %%
def gd(points, learning_rate, num_iterations):
    m = np.zeros(14)
    for i in range(num_iterations):
        m = step_gradient(points, learning_rate, m)
#         print(i, "cost : ", cost(points,m))
    return m

# %%
# when data is not scaled.
def run():
    train = np.genfromtxt("boston_train.csv", delimiter = ",")
    df = pd.DataFrame(train)
    df.insert(loc = 13, column = "14", value = [1 for i in range(379)])
    train_ = df.values
    learning_rate = 0.1
    num_iterations = 800
    m = gd(train_, learning_rate, num_iterations)
    print(m)
    return m

# %%
def predict(m):
    x_test = np.genfromtxt("boston_test.csv", delimiter = ",") 
    df = pd.DataFrame(x_test)
    df['13'] = 1
    x = df.values
    y_pred = []
    for i in range(len(x_test)):
        y_pred.append((m*x[i,:]).sum())
    print(y_pred) 
    return y_pred

# %%
m1 = run()
# Out:
# [-9.38078493e-01  7.41028076e-01  1.16730518e-02  7.80875769e-01
#  -2.17455491e+00  2.35429867e+00  1.23336019e-01 -2.95232485e+00
#   2.53292900e+00 -1.70285775e+00 -2.25151812e+00  5.88353501e-01
#  -4.26368049e+00  2.26772334e+01]

# %%
y_pred = predict(m1)
print(y_pred)
# Out:
# [12.433279346537066, 29.033656878474517, 22.371646865907856, 24.477773353971845, 20.60169442657285, 2.7253393037140796, 30.39998098472362, 24.86119412722157, 18.65725628010204, 23.53985827199565, 24.113968204063575, 17.711444580056483, 17.44003230501835, 21.65357506657009, 42.31138577398852, 23.849757243900417, 24.475731788935438, 27.538743665360826, 20.236078300095095, 31.15157122354562, 23.78240533126209, 25.009789032309254, 33.95768204602344, 36.43515027176179, 32.04099359856922, 16.713215627410133, 23.471771643950323, 32.93830501455484, 25.180684174226553, 33.710088045130256, 16.8858087019265, 26.02762389086103, 23.270404590582714, 25.477586723235074, 15.009465622802718, 29.585756967614397, 26.248212621517435, 20.372478704240777, 24.436799231127008, 9.447070542519253, 8.380957986301677, 29.013917545071337, 29.59086153570418, 19.757577752941973, 20.37196190729917, 3.1444214468746736, 39.52419941326093, 25.71741242239709, 30.377269087161515, 16.79452887618615, 17.890880881774113, 41.02571796371291, 17.572384157382043, 20.89664375075783, 15.598382598933776, 21.413936855636173, 18.454364130998073, 23.15576530127029, 13.672456291289985, 17.235733140627943, 15.027109205362493, 29.151313786122817, 25.171682285947774, 25.497493162104565, 17.211859035895394, 17.429366986953593, 34.70372491234936, 17.013403631714723, 27.107228093776516, 22.546948979133788, 29.25338948297741, 27.110177871131718, 17.73402359012048, 5.747042812667576, 36.87651807398299, 25.091942342420914, 30.150521941966097, 27.24079619817186, 16.25218116742184, 32.635434563419935, 19.27350831497449, 22.654190068136728, 22.22940198358461, 8.550838055628464, 17.33053945675631, 29.17592044165426, 27.208355521787492, 5.885763064068119, 21.91459276156562, 20.115492520521006, 22.17
alg1.fit(x_train,y_train)

# slope and intercept of the best fit line obtained.
m = alg1.coef_
c = alg1.intercept_
print("m = ", m)
print("c = ", c)
# Out:
# m =  [-0.93808077  0.74103443  0.01169157  0.78087372 -2.1745575   2.35429653
#   0.1233381  -2.95232355  2.53296817 -1.7029037  -2.25151962  0.58835429
#  -4.26368155]
# c =  22.677233263858266

# %% [markdown]
# ### When data is scaled.

# %%
def step_gradient(x_train, y_train, learning_rate, m):
    mslope = np.zeros(14)
    M = len(x_train)
    for i in range(M):
        x = np.array(x_train[i,:])
        y = y_train[i]
        mslope += (-2/M)*(y-(m*x).sum())*x
    new_m = m - learning_rate*mslope
    return new_m

# %%
def cost(x_train, y_train, m):
    C = 0
    M = len(x_train)
    for i in range(M):
        x = np.array(x_train[i,:])
        y = y_train[i]
        C += (1/M)*((y-(m*x).sum())**2)
    return C

# %%
def gd(x_train, y_train, learning_rate, num_iterations):
    m = np.zeros(14)
    for i in range(num_iterations):
        m = step_gradient(x_train, y_train, learning_rate, m)
#         print(i, "cost : ", cost(x_train, y_train,m))
    return m

# %%
# when data is scaled.
def run_scaled_data():
    train = np.genfromtxt("boston_train.csv", delimiter = ",")
    scaler = preprocessing.StandardScaler()
    scaler.fit(train[:,0:13])
    train_scaled = scaler.transform(train[:,0:13])
    df = pd.DataFrame(train_scaled)
    df['14'] = 1
    xtrain = df.values
    learning_rate = 0.1
    num_iterations = 700
    m = gd(xtrain, train[:,13], learning_rate, num_iterations)
    print(m)
    return m

# %%
def predict(m):
    x_test = np.genfromtxt("boston_test.csv", delimiter = ",") 
    df = pd.DataFrame(x_test)
    df['13'] = 1
    x = df.values
    y_pred = []
    for i in range(len(x_test)):
        y_pred.append((m*x[i,:]).sum())
    print(y_pred) 
    return y_pred

# %%
m2 = run_scaled_data()
# Out:
# [-1.00005739e+00  7.40624515e-01  1.17810008e-02  8.18062932e-01
#  -2.17092717e+00  2.35396084e+00  1.21342911e-01 -3.03040917e+00
#   2.57055841e+00 -1.73437710e+00 -2.24920467e+00  5.96855427e-01
#  -4.32352430e+00  2.26094987e+01]

# %%
y_pred_scaled = predict(m2)
print(y_pred_scaled)
# Out:
# [12.196602810194122, 28.952413356535068, 22.400405053912266, 24.35732407655468, 20.574847709733607, 2.5447937937046845, 30.41932846677041, 24.83589560422484, 18.6122372325584, 23.524308353969058, 24.06322076737465, 17.63474996473603, 17.232468432470718, 21.541490341182424, 42.51329888669737, 23.71296815290193, 24.408103321145347, 27.538748566284333, 20.0633460869559, 31.165769106068133, 23.75681328848843, 24.975133597024804, 34.01319591588959, 36.601458881367236, 31.890330617869232, 16.623270175180252, 23.44695831203192, 32.90417437309901, 25.26903296864209, 33.87273079488374, 16.793421639364084, 25.99447916163242, 23.28684815112705, 25.409577294719274, 14.805521776307076, 29.606592399058133, 26.188528043414642, 20.34131536742342, 24.3047300114918, 9.18716063547152, 8.206776777302512, 28.934712017509018, 29.43751166508499, 19.743289986225378, 20.31314990862422, 2.897872018998207, 39.57900696009918, 25.695724627832043, 30.22316123328402, 16.701905788182607, 17.809090901432057, 41.004260861594474, 17.486685860769224, 20.89616554475801, 15.487166913269238, 21.369354994966194, 18.363360861035822, 23.131769275823345, 13.549063268586725, 17.15050123614862, 14.747590315644569, 29.179486084224695, 25.132562054039393, 25.471
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
scaler.fit(train[:,0:13])
train_data = scaler.transform(train[:,0:13])

# defining X_train and y_train data 
x_train = train_data
y_train = train[:,13]

# fitting into algorithm
from sklearn.linear_model import LinearRegression
alg1 = LinearRegression()
alg1.fit(x_train,y_train)

# slope and intercept of the best fit line obtained.
m = alg1.coef_
c = alg1.intercept_
print("m = ", m)
print("c = ", c)
# print(train_data)
# train_
y_predic = alg1.predict(x_test)
for i in y_predic:
    print(i,end=", ")
# Out:
# m =  [-1.00007026  0.74065794  0.01188043  0.81805153 -2.17094041  2.35394967
#   0.12135345 -3.03040197  2.57076841 -1.73462464 -2.24921247  0.59685962
#  -4.32352985]
# c =  22.609498680738785
# 12.196621562574151, 28.952503310357752, 22.40039498566806, 24.35739709432068, 20.57471737200281, 2.5447542453140706, 30.419453825503503, 24.83593158354426, 18.61220433568881, 23.524311306794747, 24.06322650222544, 17.63471930043452, 17.23231312012479, 21.54142586278175, 42.513251375843126, 23.71290348921064, 24.408109096643184, 27.538658641176156, 20.0632863660881, 31.16568126633394, 23.756673276871048, 24.97516296130414, 34.013214777149145, 36.601492060664484, 31.89027562977366, 16.62332613761948, 23.446929445995153, 32.90404072087024, 25.269121954475565, 33.87272415881873, 16.79338778905147, 25.994398230034935, 23.286827649743685, 25.40959505947991, 14.805523700181, 29.606553026387715, 26.18852888679228, 20.34119765106667, 24.30481585366218, 9.187150903213496, 8.206819907088782, 28.934744984605576, 29.4374711927929, 19.7432482639912, 20.31318207990055, 2.8978957860559227, 39.579018678533714, 25.695725313350472, 30.223307930838704, 16.70192571472346, 17.80912007953452, 41.00440773193191, 17.486705476166783, 20.89607123879958, 15.48713837650766, 21.369423802082302, 18.36336472241806, 23.131764490232918, 13.549032462801637, 17.150531179835237, 14.74755796628564, 29.179486472580926, 25.13246472072613, 25.47167858057073, 17.164454827437368, 17.31754717876422, 34.74217403024326, 16.925428472187455, 27.22717713518994, 22.50009977553255, 29.25091247224764, 27.089272659191494, 17.697722854262977, 5.497698758470346, 36.808117177754056, 25.032367111841438, 30.137347338908313, 27.22600994723132, 16.105510170565413, 32.458071593040074, 19.263974294447557, 22.64300740240182, 22.119523875758286, 8.270749211769227, 17.242674267064544, 29.12968734918493, 27.074467216475217, 5.682514562933402, 21.919723186038574, 20.077323262309562, 22.089071539161967, 20.50032314554974, 20.788607614277314, 13.087668414146199, 19.64852853126085, 26.029812023158065, 40.23126821168069, 19.754813713224802, 33.682908140952094, 27.08927793163324, 28.781581558588005, 21.964118180589, 26.001960454935723, 31.343966320787082, 17.05327142523572, 26.35919927505182, 21.31582173545509, 36.650813053062635, 21.949542464539707, 16.589680196162924, 27.42911698181001, -0.336323235721693, 13.767242507822182, 16.2904503507095, 35.82283940931745, 20.814160147800344, 20.700805879197272, 25.324406580635053, 21.6641266876246, 18.845318586741165, 13.382856091848058, 35.63511622016672, 23.027511561147556, 24.919181670630845, 17.173328465089476, 20.72247919787197, 14.668723611183816,
